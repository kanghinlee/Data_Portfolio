# %%
import seaborn as sns

# Simple Linear Regression Project

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris[['petal_length', 'petal_width']]

# %%
x = iris['petal_length']
y = iris['petal_width']

# %%
import matplotlib.pyplot as plt

# Scatter Plot between x (length) vs y (width)
plt.scatter(x,y)
plt.xlabel("petal_length")
plt.ylabel("petal_width")

# Note
# The plot shows position Correlation between Petal Length(X) and Petal Width(Y)
# Slight bias between 2 < x < 3, as there is no observes between the range
# Variant increase as Length increases (i.e. data is more spread out towards X > 5)
# Out:
# Text(0, 0.5, 'petal_width')

# %%
# Split Train and Test Dataset

from sklearn.model_selection import train_test_split

# Keep 40% of testing data for test dataset (0.4)
# Keep a constrain to "random_state" to 42
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.4, random_state = 42)

# %%
import numpy as np

# Convert series into array (i.e. 2 dimensional data)
x_train = np.array(x_train).reshape(-1,1)
x_test = np.array(x_test).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
#Intercept
c
# Out:
# -0.3736970002822666

# %%
m = lr.coef_
# Gradient / x coefficient
m
# Out:
# array([0.42061483])

# %%
y_pre_train1 = lr.predict(x_train)
y_pre_train1
# Out:
# array([1.68731565, 0.42547117, 0.29928672, 0.34134821, 1.39288527,
#        0.25722524, 1.39288527, 2.44442234, 0.21516376, 1.43494675,
#        1.72937713, 0.21516376, 1.64525417, 1.77143862, 1.30876231,
#        1.51906972, 1.89762306, 1.30876231, 0.34134821, 1.01433193,
#        1.85556158, 0.21516376, 0.13104079, 1.22463934, 1.72937713,
#        0.25722524, 1.77143862, 0.25722524, 0.29928672, 1.64525417,
#        0.88814748, 2.02380751, 1.77143862, 1.98174603, 2.19205344,
#        1.30876231, 0.21516376, 0.08897931, 1.72937713, 2.14999196,
#        0.25722524, 0.21516376, 0.17310227, 1.68731565, 1.98174603,
#        0.21516376, 1.93968455, 2.14999196, 0.17310227, 1.60319269,
#        1.5611312 , 1.64525417, 1.60319269, 1.85556158, 0.29928672,
#        1.89762306, 1.39288527, 1.8135001 , 1.09845489, 1.26670082,
#        1.5611312 , 0.17310227, 1.5611312 , 1.47700824, 0.25722524,
#        1.35082379, 2.27617641, 2.02380751, 0.25722524, 1.01433193,
# ...

# %%
# Scatter Plot between x (length) vs y (width)
plt.scatter(x_train,y_train)
plt.plot(x_train,y_pre_train1, color = 'red')
plt.xlabel("petal_length")
plt.ylabel("petal_width")
# Out:
# Text(0, 0.5, 'petal_width')

# %%
# validation using test model

# Y prediction using test data (X Test)
y_pre_test1 = lr.predict(x_test)

# Scatter Plot between x (length) vs y (width)
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pre_test1, color = 'red')
plt.xlabel("petal_length")
plt.ylabel("petal_width")
# The plot shows Position Correlation between X and Y with slight bias between 2 < x < 3
# Out:
# Text(0, 0.5, 'petal_width')
